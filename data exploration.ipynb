# %%
from google.colab import drive
drive.mount('/content/drive')

import numpy as np
import pandas as pd
# Out:
# Mounted at /content/drive

# %%
# download content from Kaggle
# !cp /content/drive/MyDrive/kaggle.json ~/.kaggle/kaggle.json
# !kaggle competitions download -c santa-2021

# !unzip distance_matrix.csv.zip
# !unzip wildcards.csv.zip
# !mkdir /content/data/
# !mv distance_matrix.csv /content/data/
# !mv permutations.csv /content/data/
# !mv sample_submission.csv /content/data/
# !mv wildcards.csv /content/data/

# %%
# read csvs

dist_matrix = np.loadtxt('/content/data/distance_matrix.csv', delimiter=',', dtype = 'str')
permut = np.loadtxt('/content/data/permutations.csv', delimiter=',', dtype = 'str')
wildcards = np.loadtxt('/content/data/wildcards.csv', delimiter=',', dtype = 'str')
sample = np.loadtxt('/content/data/sample_submission.csv', delimiter=',', dtype = 'str')

# %%
sample
# Out:
# array(['schedule',
# ...
